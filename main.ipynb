# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

control_1 = pd.read_csv("D:/Users/DEBJIT DAS/Mental-Health-Prediction/data/control/control_1.csv")

condition_1 = pd.read_csv("D:/Users/DEBJIT DAS/Mental-Health-Prediction/data/condition/condition_1.csv")

print(f'control_1.shape: {control_1.shape}')
print(f'condition_1.shape: {condition_1.shape}')
# Out:
# control_1.shape: (51611, 3)
# condition_1.shape: (23244, 3)
