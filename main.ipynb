# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data.csv")

# %%
df.head()
# Out:
#    id  age  gender         region income_level education_level  \
# 0   1   40  Female           Asia         High     High School
# 1   2   27    Male         Africa    Lower-Mid          Master
# 2   3   31    Male  North America    Lower-Mid        Bachelor
# 3   4   41  Female    Middle East          Low          Master
# 4   5   26  Female         Europe    Lower-Mid        Bachelor
#
#            daily_role  device_hours_per_day  phone_unlocks  \
# 0     Part-time/Shift                  3.54             45
# 1  Full-time Employee                  5.65            100
# 2  Full-time Employee                  8.87            181
# 3      Caregiver/Home                  4.05             94
# 4  Full-time Employee                 13.07            199
#
#    notifications_per_day  ...  sleep_quality  anxiety_score  depression_score  \
# 0                    561  ...       3.353627       9.926651               5.0
# 1                    393  ...       2.908147       4.000000               4.0
# 2                    231  ...       2.889213       4.000000               8.0
# 3                    268  ...       3.097488       7.093357               9.0
# 4                     91  ...       2.786098       7.028125              15.0
#
#    stress_level  happiness_score  focus_score  high_risk_flag  device_type  \
# 0      6.593289              8.0         23.0               0      Android
# 1      4.126926              8.1         35.0               0       Laptop
# 2      1.429139              7.6         15.0               0      Android
# 3      4.995512              7.8         28.0               1       Tablet
# 4      9.448757              4.2         70.0               1      Android
#
#    productivity_score  digital_dependence_score
# 0           70.000000                 25.700000
# 1           64.000000                 30.100000
# 2           65.299301                 40.600000
# 3           80.000000                 36.684152
# 4           65.299301                 48.400000
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        3500 non-null   int64
#  1   age                       3500 non-null   int64
#  2   gender                    3500 non-null   str
#  3   region                    3500 non-null   str
#  4   income_level              3500 non-null   str
#  5   education_level           3500 non-null   str
#  6   daily_role                3500 non-null   str
#  7   device_hours_per_day      3500 non-null   float64
#  8   phone_unlocks             3500 non-null   int64
#  9   notifications_per_day     3500 non-null   int64
#  10  social_media_mins         3500 non-null   int64
#  11  study_mins                3500 non-null   int64
#  12  physical_activity_days    3500 non-null   float64
#  13  sleep_hours               3500 non-null   float64
#  14  sleep_quality             3500 non-null   float64
#  15  anxiety_score             3500 non-null   float64
#  16  depression_score          3500 non-null   float64
#  17  stress_level              3500 non-null   float64
#  18  happiness_score           3500 non-null   float64
#  19  focus_score               3500 non-null   float64
#  20  high_risk_flag            3500 non-null   int64
#  21  device_type               3500 non-null   str
#  22  productivity_score        3500 non-null   float64
#  23  digital_dependence_score  3500 non-null   float64
# dtypes: float64(11), int64(7), str(6)
# memory usage: 656.4 KB

# %%
df.shape
# Out:
# (3500, 24)

# %%
df.describe().T
# Out:
#                            count         mean          std    min         25%  \
# id                        3500.0  1750.500000  1010.507298   1.00  875.750000
# age                       3500.0    28.078571     9.352385  13.00   21.000000
# device_hours_per_day      3500.0     7.317677     3.239838   0.28    4.867500
# phone_unlocks             3500.0   147.107429    67.770656   9.00   96.000000
# notifications_per_day     3500.0   335.117143   239.678612  22.00  170.000000
# social_media_mins         3500.0   159.362857   132.748048   0.00   68.000000
# study_mins                3500.0   108.116571    79.796273   0.00   42.000000
# physical_activity_days    3500.0     3.350000     1.877976   0.00    2.000000
# sleep_hours               3500.0     7.254481     1.291879   3.00    6.410545
# sleep_quality             3500.0     2.708848     1.101105   1.00    1.919438
# anxiety_score             3500.0     7.183858     5.043220   0.00    4.000000
# depression_score          3500.0     8.830000     5.738959   0.00    4.000000
# stress_level              3500.0     5.076560     3.403503   1.00    1.341488
# happiness_score           3500.0     6.418568     3.019828   0.00    4.000000
# focus_score               3500.0    41.598600    23.764574   0.00   24.750000
# high_risk_flag            3500.0     0.201429     0.401125   0.00    0.000000
# productivity_score        3500.0    65.299301     9.664716  33.00   59.000000
# digital_dependence_score  3500.0    36.684152    14.115504   5.60   26.200000
#
#                                   50%          75%          max
# id                        1750.500000  2625.250000  3500.000000
# age                         27.000000    34.000000    50.000000
# device_hours_per_day         6.760000     9.152500    17.160000
# phone_unlocks              136.000000   187.000000   374.000000
# notifications_per_day      268.000000   434.000000  1211.000000
# social_media_mins          119.000000   204.000000   631.000000
# study_mins                 102.000000   163.000000   418.000000
# physical_activity_days       3.000000     5.000000     7.000000
# sleep_hours                  7.291580     8.162298    11.004566
# sleep_quality                2.907819     3.276968     5.000000
# anxiety_score                6.000000     8.845008    27.154217
# depression_score             8.000000    13.000000    27.000000
# stress_level                 4.809726     8.794302    10.000000
# happiness_score              7.500000     8.900000    10.000000
# focus_score                 44.000000    59.000000   100.000000
# high_risk_flag               0.000000     0.000000     1.000000
# productivity_score          65.299301    71.000000    95.000000
# digital_dependence_score    35.300000    45.100000    89.200000

# %%
df.isnull().sum()
# Out:
# id                          0
# age                         0
# gender                      0
# region                      0
# income_level                0
# education_level             0
# daily_role                  0
# device_hours_per_day        0
# phone_unlocks               0
# notifications_per_day       0
# social_media_mins           0
# study_mins                  0
# physical_activity_days      0
# sleep_hours                 0
# sleep_quality               0
# anxiety_score               0
# depression_score            0
# stress_level                0
# happiness_score             0
# focus_score                 0
# high_risk_flag              0
# device_type                 0
# productivity_score          0
# digital_dependence_score    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns="id")

# %%
df.head()
# Out:
#    age  gender         region income_level education_level  \
# 0   40  Female           Asia         High     High School
# 1   27    Male         Africa    Lower-Mid          Master
# 2   31    Male  North America    Lower-Mid        Bachelor
# 3   41  Female    Middle East          Low          Master
# 4   26  Female         Europe    Lower-Mid        Bachelor
#
#            daily_role  device_hours_per_day  phone_unlocks  \
# 0     Part-time/Shift                  3.54             45
# 1  Full-time Employee                  5.65            100
# 2  Full-time Employee                  8.87            181
# 3      Caregiver/Home                  4.05             94
# 4  Full-time Employee                 13.07            199
#
#    notifications_per_day  social_media_mins  ...  sleep_quality  \
# 0                    561                 98  ...       3.353627
# 1                    393                174  ...       2.908147
# 2                    231                595  ...       2.889213
# 3                    268                 18  ...       3.097488
# 4                     91                147  ...       2.786098
#
#    anxiety_score  depression_score  stress_level  happiness_score  \
# 0       9.926651               5.0      6.593289              8.0
# 1       4.000000               4.0      4.126926              8.1
# 2       4.000000               8.0      1.429139              7.6
# 3       7.093357               9.0      4.995512              7.8
# 4       7.028125              15.0      9.448757              4.2
#
#    focus_score  high_risk_flag  device_type  productivity_score  \
# 0         23.0               0      Android           70.000000
# 1         35.0               0       Laptop           64.000000
# 2         15.0               0      Android           65.299301
# 3         28.0               1       Tablet           80.000000
# 4         70.0               1      Android           65.299301
#
#    digital_dependence_score
# 0                 25.700000
# 1                 30.100000
# 2                 40.600000
# 3                 36.684152
# 4                 48.400000
#
# [5 rows x 23 columns]

# %%
numeric_df = df.select_dtypes(include=['number'])
categorial_df = df.select_dtypes(include=['object'])
# Out:
# C:\Users\DEBJIT   DAS\AppData\Local\Temp\ipykernel_14260\985164728.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorial_df = df.select_dtypes(include=['object'])

# %%
numeric_df
# Out:
#       age  device_hours_per_day  phone_unlocks  notifications_per_day  \
# 0      40                  3.54             45                    561
# 1      27                  5.65            100                    393
# 2      31                  8.87            181                    231
# 3      41                  4.05             94                    268
# 4      26                 13.07            199                     91
# ...   ...                   ...            ...                    ...
# 3495   15                  6.41            119                    308
# 3496   28                  4.21             55                    415
# 3497   44                 11.51            146                    119
# 3498   29                  5.13             63                    180
# 3499   27                  4.03             87                    197
#
#       social_media_mins  study_mins  physical_activity_days  sleep_hours  \
# 0                    98          34                     7.0     9.123800
# 1                   174         102                     2.0     8.837517
# 2                   595         140                     1.0     6.486743
# 3                    18         121                     4.0     7.600504
# 4                   147          60                     1.0     5.197962
# ...                 ...         ...                     ...          ...
# 3495                111          11                     3.0     6.128898
# 3496                136         155                     4.0     6.699823
# 3497                 41         206                     6.0     6.590077
# 3498                182         153                     2.0     9.626066
# 3499                158         200                     2.0     6.546425
#
#       sleep_quality  anxiety_score  depression_score  stress_level  \
# 0          3.353627       9.926651               5.0      6.593289
# 1          2.908147       4.000000               4.0      4.126926
# 2          2.889213       4.000000               8.0      1.429139
# 3          3.097488       7.093357               9.0      4.995512
# 4          2.786098       7.028125              15.0      9.448757
# ...             ...            ...               ...           ...
# 3495       2.950001       4.772862               9.0      7.076726
# 3496       3.124953       5.520824               2.0      1.000000
# 3497       2.269790       8.518051              11.0      1.783568
# 3498       4.902579       4.238655               8.0     10.000000
# 3499       4.780323       2.000000               5.0      1.178647
#
#       happiness_score  focus_score  high_risk_flag  productivity_score  \
# 0                 8.0         23.0               0           70.000000
# 1                 8.1         35.0               0           64.000000
# 2                 7.6         15.0               0           65.299301
# 3                 7.8         28.0               1           80.000000
# 4                 4.2         70.0               1           65.299301
# ...               ...          ...             ...                 ...
# 3495              2.4         59.0               0           84.000000
# 3496              8.9         27.0               1           73.000000
# 3497              7.6         56.0               0           65.000000
# 3498              2.8         52.0               0           63.000000
# 3499              8.4         58.0               0           61.000000
#
#       digital_dependence_score
# 0                    25.700000
# 1                    30.100000
# 2                    40.600000
# 3                    36.684152
# 4                    48.400000
# ...                        ...
# 3495                 29.600000
# 3496                 23.200000
# 3497                 42.400000
# 3498                 20.500000
# 3499                 20.200000
#
# [3500 rows x 17 columns]

# %%
categorial_df
# Out:
#       gender         region income_level education_level          daily_role  \
# 0     Female           Asia         High     High School     Part-time/Shift
# 1       Male         Africa    Lower-Mid          Master  Full-time Employee
# 2       Male  North America    Lower-Mid        Bachelor  Full-time Employee
# 3     Female    Middle East          Low          Master      Caregiver/Home
# 4     Female         Europe    Lower-Mid        Bachelor  Full-time Employee
# ...      ...            ...          ...             ...                 ...
# 3495  Female         Africa          Low     High School     Part-time/Shift
# 3496  Female         Europe         High        Bachelor     Part-time/Shift
# 3497  Female         Europe    Lower-Mid        Bachelor     Part-time/Shift
# 3498  Female  North America          Low          Master  Full-time Employee
# 3499    Male    Middle East          Low        Bachelor  Full-time Employee
#
#      device_type
# 0        Android
# 1         Laptop
# 2        Android
# 3         Tablet
# 4        Android
# ...          ...
# 3495      Laptop
# 3496      Laptop
# 3497     Android
# 3498      Laptop
# 3499      Laptop
#
# [3500 rows x 6 columns]

# %%
categorial_df.columns
# Out:
# Index(['gender', 'region', 'income_level', 'education_level', 'daily_role',
#        'device_type'],
#       dtype='str')

# %%
cols = ['gender', 'region', 'income_level', 
        'education_level', 'daily_role', 'device_type']

fig, axes = plt.subplots(3, 2, figsize=(14, 12))

axes = axes.flatten()  
for i in range(len(cols)):
    
    col = cols[i]
    
    categorial_df[col].value_counts().plot(
        kind='barh',
        color=plt.cm.tab10.colors,
        ax=axes[i]
    )
    
    axes[i].set_title(col + " Distribution")
    axes[i].set_xlabel("Count")
    axes[i].set_ylabel("Category")
    axes[i].invert_yaxis()

plt.tight_layout()
plt.show()

# %%
cols = ['gender', 'region', 'income_level', 
        'education_level', 'daily_role', 'device_type']
fig , axes = plt.subplots(3,2,figsize = (12,10))
axes = axes.flatten()
for i in range(len(cols)):
    col = cols[i]
    
    categorial_df[col].value_counts().plot(
        kind="pie",
        autopct ='%1.1f%%',
        color=plt.cm.tab10.colors,
        ax=axes[i]
    )
    plt.tight_layout()

# %%
numeric_df.columns
# Out:
# Index(['age', 'device_hours_per_day', 'phone_unlocks', 'notifications_per_day',
#        'social_media_mins', 'study_mins', 'physical_activity_days',
#        'sleep_hours', 'sleep_quality', 'anxiety_score', 'depression_score',
#        'stress_level', 'happiness_score', 'focus_score', 'high_risk_flag',
#        'productivity_score', 'digital_dependence_score'],
#       dtype='str')

# %%
print(len(numeric_df.columns))
# Out:
# 17

# %%
numeric_df = numeric_df.drop(columns=['high_risk_flag'])

# %%
cols = ['age', 'device_hours_per_day', 'phone_unlocks', 'notifications_per_day',
        'social_media_mins', 'study_mins', 'physical_activity_days',
        'sleep_hours', 'sleep_quality', 'anxiety_score', 'depression_score',
        'stress_level', 'happiness_score', 'focus_score',
        'productivity_score', 'digital_dependence_score']


fig, axes = plt.subplots(8, 2, figsize=(16, 30))

axes = axes.flatten()

for i, col in enumerate(cols):
    
    sns.kdeplot(
        data=df,
        x=col,
        hue='high_risk_flag',
        fill=True,
        common_norm=False,
        alpha=0.5,
        ax=axes[i]
    )
    
    axes[i].set_title(f"{col} by Risk Flag")

plt.tight_layout()
plt.show()

# %%
cols = ['age', 'device_hours_per_day', 'phone_unlocks', 'notifications_per_day',
        'social_media_mins', 'study_mins', 'physical_activity_days',
        'sleep_hours', 'sleep_quality', 'anxiety_score', 'depression_score',
        'stress_level', 'happiness_score', 'focus_score',
        'productivity_score', 'digital_dependence_score']

fig, axes = plt.subplots(8, 2, figsize=(16, 30))
axes = axes.flatten()

for i, col in enumerate(cols):
    sns.boxenplot(
        data=df,
        x=col,
        hue='high_risk_flag',
        palette="Set2",
        width=0.5,
        linewidth=1.2,
        
        ax=axes[i]
    )

    axes[i].set_title(f"{col} by Risk Flag")


plt.tight_layout()
plt.show()

# %%
corr = numeric_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(
    corr,
    annot=True,
    fmt= '.2f',
    cmap="coolwarm",
    center= 0,
    square= True,
    linewidths=1
    
    
)
plt.tight_layout()
plt.show()
